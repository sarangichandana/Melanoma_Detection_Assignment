# %% [markdown]
# ## <b>Problem statement: </b>
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# ### reading the data

# %% [markdown]
# #### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <b>This assignment uses a dataset of about 2357 images of skin cancer types. Each of the train and test subdirectories in the dataset has 9 subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.</b>

# %%
# Defining the path for train and test images
## Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load the data using keras.preprocessing
#  load these images of disk using the image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write train dataset here
## use seed=123 while creating a dataset using tf.keras.preprocessing.image_dataset_from_directory
## resize images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write validation dataset here
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List all the classes of skin cancer and store them in a list. 
# we can find the class names in the class_names attribute on these datasets. 
# These corresponds to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualizing the data
# #### create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)
### we can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model
# Choose an appropirate optimiser and loss function for model training

# %%
### choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 180, 180, 32)      2432
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d_4 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_5 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_6 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_7 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 64)        0
#
#  flatten_1 (Flatten)         (None, 7744)              0
#
#  dense_1 (Dense)             (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 268s 2s/step - loss: 2.1014 - accuracy: 0.1775 - val_loss: 2.0433 - val_accuracy: 0.1499
# Epoch 2/30
# 56/56 [==============================] - 5s 89ms/step - loss: 2.0292 - accuracy: 0.1830 - val_loss: 2.0227 - val_accuracy: 0.1924
# Epoch 3/30
# 56/56 [==============================] - 5s 90ms/step - loss: 2.0265 - accuracy: 0.1942 - val_loss: 2.0333 - val_accuracy: 0.2058
# Epoch 4/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0329 - accuracy: 0.2065 - val_loss: 2.0287 - val_accuracy: 0.1924
# Epoch 5/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0199 - accuracy: 0.1920 - val_loss: 2.0254 - val_accuracy: 0.2058
# Epoch 6/30
# 56/56 [==============================] - 5s 89ms/step - loss: 2.0203 - accuracy: 0.1908 - val_loss: 2.0274 - val_accuracy: 0.2081
# Epoch 7/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9968 - accuracy: 0.2048 - val_loss: 1.9611 - val_accuracy: 0.2371
# Epoch 8/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9862 - accuracy: 0.2394 - val_loss: 1.9608 - val_accuracy: 0.2349
# Epoch 9/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9681 - accuracy: 0.2360 - val_loss: 1.9707 - val_accuracy: 0.2416
# Epoch 10/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9462 - accuracy: 0.2500 - val_loss: 1.9824 - val_accuracy: 0.2550
# Epoch 11/30
# 56/56 [==============================] - 5s 90ms/step - loss: 2.0430 - accuracy: 0.2411 - val_loss: 1.9408 - val_accuracy: 0.2752
# Epoch 12/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9607 - accuracy: 0.2355 - val_loss: 2.0042 - val_accuracy: 0.1834
# Epoch 13/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.9659 - accuracy: 0.2316 - val_loss: 2.0391 - val_accuracy: 0.2148
# Epoch 14/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.9293 - accuracy: 0.2416 - val_loss: 2.1084 - val_accuracy: 0.2081
# Epoch 15/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9219 - accuracy: 0.2567 - val_loss: 2.0002 - val_accuracy: 0.2573
# Epoch 16/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.8946 - accuracy: 0.2679 - val_loss: 2.0428 - val_accuracy: 0.2573
# Epoch 17/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.8777 - accuracy: 0.2768 - val_loss: 1.9834 - val_accuracy: 0.2573
# Epoch 18/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.8758 - accuracy: 0.2874 - val_loss: 2.0172 - val_accuracy: 0.2662
# Epoch 19/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.8285 - accuracy: 0.2857 - val_loss: 2.1511 - val_accuracy: 0.2707
# Epoch 20/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.8164 - accuracy: 0.2846 - val_loss: 2.0317 - val_accuracy: 0.2752
# Epoch 21/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.7889 - accuracy: 0.3136 - val_loss: 2.0768 - val_accuracy: 0.2908
# Epoch 22/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.7694 - accuracy: 0.3225 - val_loss: 2.2511 - val_accuracy: 0.2841
# Epoch 23/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.7220 - accuracy: 0.3404 - val_loss: 2.0784 - val_accuracy: 0.2864
# Epoch 24/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.6677 - accuracy: 0.3761 - val_loss: 2.3188 - val_accuracy: 0.3221
# Epoch 25/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.5894 - accuracy: 0.3901 - val_loss: 2.1656 - val_accuracy: 0.2931
# Epoch 26/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.5538 - accuracy: 0.4286 - val_loss: 2.2361 - val_accuracy: 0.2953
# Epoch 27/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.4969 - accuracy: 0.4353 - val_loss: 2.3310 - val_accuracy: 0.3445
# Epoch 28/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.4204 - accuracy: 0.4799 - val_loss: 2.3192 - val_accuracy: 0.2975
# Epoch 29/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.3506 - accuracy: 0.4967 - val_loss: 2.4679 - val_accuracy: 0.3423
# Epoch 30/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.2541 - accuracy: 0.5463 - val_loss: 2.3678 - val_accuracy: 0.3937

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Observation**
#
# - Here the model is overfitting because of the differences in loss functions in training & test around the 10-11th epoch
#
# - The accuracy is around 75-80% because there are enough features to remember the pattern.

# %%
# Select a suitable data augmentation approach after examining the model fit history to determine whether it is underfit or overfit. 

data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# visualizing how augmentation strategy works for one instance of training image.

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## we can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## train your model for 30 epochs
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 9s 106ms/step - loss: 2.0511 - accuracy: 0.2065 - val_loss: 1.8916 - val_accuracy: 0.3087
# Epoch 2/30
# 56/56 [==============================] - 6s 98ms/step - loss: 1.9414 - accuracy: 0.2506 - val_loss: 1.9084 - val_accuracy: 0.2953
# Epoch 3/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.8168 - accuracy: 0.3320 - val_loss: 1.8118 - val_accuracy: 0.3356
# Epoch 4/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.7207 - accuracy: 0.3555 - val_loss: 1.7086 - val_accuracy: 0.3736
# Epoch 5/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.6128 - accuracy: 0.4235 - val_loss: 1.5207 - val_accuracy: 0.4877
# Epoch 6/30
# 56/56 [==============================] - 5s 98ms/step - loss: 1.5631 - accuracy: 0.4487 - val_loss: 1.4973 - val_accuracy: 0.5056
# Epoch 7/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.5069 - accuracy: 0.4609 - val_loss: 1.6079 - val_accuracy: 0.4295
# Epoch 8/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.4641 - accuracy: 0.4855 - val_loss: 1.5378 - val_accuracy: 0.5056
# Epoch 9/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.4354 - accuracy: 0.5050 - val_loss: 1.4833 - val_accuracy: 0.5145
# Epoch 10/30
# 56/56 [==============================] - 6s 101ms/step - loss: 1.4469 - accuracy: 0.4922 - val_loss: 1.4495 - val_accuracy: 0.5034
# Epoch 11/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3896 - accuracy: 0.5095 - val_loss: 1.4617 - val_accuracy: 0.5213
# Epoch 12/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.4391 - accuracy: 0.4905 - val_loss: 1.5538 - val_accuracy: 0.4497
# Epoch 13/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3951 - accuracy: 0.5011 - val_loss: 1.4423 - val_accuracy: 0.5101
# Epoch 14/30
# 56/56 [==============================] - 6s 101ms/step - loss: 1.3443 - accuracy: 0.5413 - val_loss: 1.4203 - val_accuracy: 0.5056
# Epoch 15/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3164 - accuracy: 0.5240 - val_loss: 1.4970 - val_accuracy: 0.4966
# Epoch 16/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.3214 - accuracy: 0.5318 - val_loss: 1.4191 - val_accuracy: 0.5101
# Epoch 17/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3413 - accuracy: 0.5195 - val_loss: 1.4097 - val_accuracy: 0.5190
# Epoch 18/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3356 - accuracy: 0.5257 - val_loss: 1.4413 - val_accuracy: 0.5101
# Epoch 19/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.3578 - accuracy: 0.5112 - val_loss: 1.4428 - val_accuracy: 0.4966
# Epoch 20/30
# 56/56 [==============================] - 6s 98ms/step - loss: 1.2826 - accuracy: 0.5363 - val_loss: 1.4164 - val_accuracy: 0.5123
# Epoch 21/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.2397 - accuracy: 0.5647 - val_loss: 1.4963 - val_accuracy: 0.5034
# Epoch 22/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3138 - accuracy: 0.5262 - val_loss: 1.3166 - val_accuracy: 0.5347
# Epoch 23/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.3696 - accuracy: 0.5061 - val_loss: 1.5456 - val_accuracy: 0.4564
# Epoch 24/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.2942 - accuracy: 0.5229 - val_loss: 1.4875 - val_accuracy: 0.5078
# Epoch 25/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.2732 - accuracy: 0.5391 - val_loss: 1.3568 - val_accuracy: 0.5056
# Epoch 26/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.2509 - accuracy: 0.5485 - val_loss: 1.3477 - val_accuracy: 0.5280
# Epoch 27/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.2939 - accuracy: 0.5246 - val_loss: 1.4891 - val_accuracy: 0.5213
# Epoch 28/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.2594 - accuracy: 0.5564 - val_loss: 1.3134 - val_accuracy: 0.5190
# Epoch 29/30
# 56/56 [==============================] - 6s 100ms/step - loss: 1.2276 - accuracy: 0.5597 - val_loss: 1.3975 - val_accuracy: 0.5101
# Epoch 30/30
# 56/56 [==============================] - 6s 99ms/step - loss: 1.1849 - accuracy: 0.5731 - val_loss: 1.3260 - val_accuracy: 0.5123

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Observation from Second Model**
#
# - There is no certain improvement in accuracy but we can definitely see the overfitting problem has been resolved due to data augmentation
#
# - we can expand the epochs to boost the accuracy also.

# %% [markdown]
# #### Finding the distribution of classes in the training dataset.
# #### **instance:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
##
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 1     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 2     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 3     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 4     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2235  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2236  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2237  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2238  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 1     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 2     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 3     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 4     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2235  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2236  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2237  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2238  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Instances:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# Answer-1 :- **squamous cell carcinoma** has least number of samples
#
# Answer-2:- **actinic keratosis and dermatofibroma** have proportionate number of classes.
# **melanoma and pigmented benign keratosis** have proprtionate number of classes

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# #### Rectify the class imbalance
# #### we can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (1.22.4)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (8.4.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
#path_to_training_dataset="/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FC316D70910>: 100%|██████████| 500/500 [00:57<00:00,  8.65 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FC3B406EFA0>: 100%|██████████| 500/500 [00:49<00:00, 10.12 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7FC316B8C400>: 100%|██████████| 500/500 [00:46<00:00, 10.64 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FC316CE1910>: 100%|██████████| 500/500 [00:46<00:00, 10.69 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x7FC3942878B0>: 100%|██████████| 500/500 [00:51<00:00,  9.66 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FC316D80430>: 100%|██████████| 500/500 [00:47<00:00, 10.44 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FC316C812B0>: 100%|██████████| 500/500 [00:48<00:00, 10.30 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FC316C71D30>: 100%|██████████| 500/500 [00:48<00:00, 10.34 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FC316DA29A0>: 100%|██████████| 500/500 [01:00<00:00,  8.31 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train1 = pathlib.Path("/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %%
##
for i in class_names:
      
    for j in data_dir_train1.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 1     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 2     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 3     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 4     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# ...                                                 ...                ...
# 6734  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 6735  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 6736  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 6737  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 6738  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
#
# [6739 rows x 2 columns]

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    1373
# melanoma                      1260
# basal cell carcinoma          1135
# nevus                         1092
# squamous cell carcinoma        573
# vascular lesion                440
# actinic keratosis              358
# dermatofibroma                 275
# seborrheic keratosis           233
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
import pathlib
#data_dir_train1=pathlib.Path("/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
data_dir_train1=pathlib.Path("/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train")

# %%
data_dir_train1
# Out:
# PosixPath('/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train')

# %% [markdown]
# #### Create a training dataset

# %%
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 2239

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


data_dir_train1=pathlib.Path("/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 10 classes.
# Using 5392 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 10 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
## we can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ 
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### Train your model

# %%
epochs =50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 169/169 [==============================] - 43s 237ms/step - loss: nan - accuracy: 0.0200 - val_loss: nan - val_accuracy: 0.0230
# Epoch 2/50
# 169/169 [==============================] - 41s 239ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 3/50
# 169/169 [==============================] - 40s 230ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 4/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 5/50
# 169/169 [==============================] - 43s 247ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 6/50
# 169/169 [==============================] - 40s 230ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 7/50
# 169/169 [==============================] - 43s 249ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 8/50
# 169/169 [==============================] - 41s 233ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 9/50
# 169/169 [==============================] - 41s 235ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 10/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 11/50
# 169/169 [==============================] - 43s 248ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 12/50
# 169/169 [==============================] - 40s 230ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 13/50
# 169/169 [==============================] - 43s 245ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 14/50
# 169/169 [==============================] - 39s 227ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 15/50
# 169/169 [==============================] - 39s 222ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 16/50
# 169/169 [==============================] - 43s 247ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 17/50
# 169/169 [==============================] - 40s 230ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 18/50
# 169/169 [==============================] - 42s 245ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 19/50
# 169/169 [==============================] - 40s 230ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 20/50
# 169/169 [==============================] - 42s 245ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 21/50
# 169/169 [==============================] - 43s 246ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 22/50
# 169/169 [==============================] - 42s 245ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 23/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 24/50
# 169/169 [==============================] - 39s 227ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 25/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 26/50
# 169/169 [==============================] - 42s 244ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 27/50
# 169/169 [==============================] - 42s 244ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 28/50
# 169/169 [==============================] - 39s 227ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 29/50
# 169/169 [==============================] - 39s 227ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 30/50
# 169/169 [==============================] - 42s 243ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 31/50
# 169/169 [==============================] - 40s 229ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 32/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 33/50
# 169/169 [==============================] - 39s 225ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 34/50
# 169/169 [==============================] - 42s 244ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 35/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 36/50
# 169/169 [==============================] - 39s 227ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 37/50
# 169/169 [==============================] - 42s 244ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 38/50
# 169/169 [==============================] - 39s 226ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 39/50
# 169/169 [==============================] - 42s 244ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 40/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 41/50
# 169/169 [==============================] - 43s 245ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 42/50
# 169/169 [==============================] - 40s 230ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 43/50
# 169/169 [==============================] - 43s 246ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 44/50
# 169/169 [==============================] - 40s 230ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 45/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 46/50
# 169/169 [==============================] - 42s 245ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 47/50
# 169/169 [==============================] - 40s 228ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 48/50
# 169/169 [==============================] - 42s 244ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 49/50
# 169/169 [==============================] - 40s 229ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 50/50
# 169/169 [==============================] - 40s 230ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230

# %% [markdown]
# ####  Visualizing the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Analyzing results here. Did you get rid of underfitting/overfitting?

# %% [markdown]
# *  Accuracy on training data has increased by using Augmentor library *
#
# *  Model is still overfitting *
#
# *  The problem of overfitting can be solved by add more layer,neurons or adding dropout layers. *
#
# *  The Model can be further improved by tuning the hyperparameter *
